# %% [markdown]
# Adding command to top of code

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('tendulkar_ODI.csv', index_col=0)
df.head()
# Out:
#   Runs Mins  BF 4s 6s      SR Pos Dismissal Inns     Opposition      Ground  \
# 1    0    -   2  0  0       0   5    caught    2     v Pakistan  Gujranwala
# 2    0    2   2  0  0       0   5    caught    2  v New Zealand     Dunedin
# 3   36   51  39  5  0    92.3   6    caught    1  v New Zealand  Wellington
# 4   19   38  35  1  1   54.28   4    bowled    2      v England       Leeds
# 5   31   31  26  3  0  119.23   6    bowled    2      v England  Nottingham
#
#   Start Date
# 1  18-Dec-89
# 2   1-Mar-90
# 3   6-Mar-90
# 4  18-Jul-90
# 5  20-Jul-90

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 295 entries, 1 to 295
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Runs        295 non-null    object
#  1   Mins        295 non-null    object
#  2   BF          295 non-null    object
#  3   4s          295 non-null    object
#  4   6s          295 non-null    object
#  5   SR          295 non-null    object
#  6   Pos         295 non-null    object
#  7   Dismissal   295 non-null    object
#  8   Inns        295 non-null    object
#  9   Opposition  295 non-null    object
#  10  Ground      295 non-null    object
#  11  Start Date  295 non-null    object
# dtypes: object(12)
# memory usage: 30.0+ KB

# %%
df['Mins'].unique()
# Out:
# array(['-', '2', '51', '38', '31', '79', '111', '64', '12', '116', '19',
#        '122', '92', '9', '7', '42', '16', '8', '10', '25', '83', '22',
#        '69', '91', '34', '125', '13', '6', '3', '28', '184', '53', '80',
#        '101', '130', '147', '180', '30', '27', '96', '14', '175', '137',
#        '124', '198', '103', '26', '18', '20', '189', '133', '55', '128',
#        '157', '48', '57', '17', '188', '49', '109', '4', '41', '24',
#        '110', '23', '104', '21', '44', '132', '45', '33', '156', '182',
#        '155', '37', '105', '191', '61', '221', '66', '39', '195', '119',
#        '90', '200', '113', '47', '35', '197', '68', '129', '209', '82',
#        '71', '120', '60', '158', '29', '117', '173', '170', '46', '15',
#        '192', '149', '87', '76', '77', '81', '134', '54', '112', '94',
#        '52', '43', '123', '235', '176', '40', '99', '11', '206', '63',
#        '214', '86', '210', '187', '226', '78', '93', '160', '205'],
#       dtype=object)

# %%
df['Runs'] = pd.to_numeric(df['Runs'], errors='coerce')
df = df.dropna(subset=['Runs'])
df['Mins'] = df['Mins'].replace('-', 0).astype(int)

# %%
df.describe()
# Out:
#              Runs        Mins
# count  272.000000  272.000000
# mean    35.819853   60.154412
# std     36.229393   56.583593
# min      0.000000    0.000000
# 25%      6.000000   16.000000
# 50%     25.000000   42.000000
# 75%     54.000000   94.500000
# max    175.000000  214.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 272 entries, 1 to 295
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Runs        272 non-null    float64
#  1   Mins        272 non-null    int32
#  2   BF          272 non-null    object
#  3   4s          272 non-null    object
#  4   6s          272 non-null    object
#  5   SR          272 non-null    object
#  6   Pos         272 non-null    object
#  7   Dismissal   272 non-null    object
#  8   Inns        272 non-null    object
#  9   Opposition  272 non-null    object
#  10  Ground      272 non-null    object
#  11  Start Date  272 non-null    object
# dtypes: float64(1), int32(1), object(10)
# memory usage: 26.6+ KB

# %%
plt.hist(df['Runs'], bins=[0, 10, 20, 30, 40, 50, 60, 100], color='blue', edgecolor='black')
# Out:
# (array([83., 37., 29., 34., 13., 12., 45.]),
#  array([  0.,  10.,  20.,  30.,  40.,  50.,  60., 100.]),
#  <BarContainer object of 7 artists>)

# %%
plt.hist(df['4s'], bins=50, color='blue', edgecolor='black')
# Out:
# (array([67.,  0., 16.,  0.,  0., 37.,  0.,  0., 25.,  0.,  0., 12.,  0.,
#         27.,  0.,  0., 13.,  0.,  0., 12.,  0.,  0.,  3.,  0.,  0., 15.,
#          0.,  3.,  0.,  0.,  9.,  0.,  0., 16.,  0.,  0.,  3.,  0.,  3.,
#          0.,  0.,  5.,  0.,  0.,  2.,  0.,  0.,  1.,  0.,  3.]),
#  array([ 0.  ,  0.36,  0.72,  1.08,  1.44,  1.8 ,  2.16,  2.52,  2.88,
#          3.24,  3.6 ,  3.96,  4.32,  4.68,  5.04,  5.4 ,  5.76,  6.12,
#          6.48,  6.84,  7.2 ,  7.56,  7.92,  8.28,  8.64,  9.  ,  9.36,
#          9.72, 10.08, 10.44, 10.8 , 11.16, 11.52, 11.88, 12.24, 12.6 ,
#         12.96, 13.32, 13.68, 14.04, 14.4 , 14.76, 15.12, 15.48, 15.84,
#         16.2 , 16.56, 16.92, 17.28, 17.64, 18.  ]),
#  <BarContainer object of 50 artists>)

# %%
df['Runs'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25     6.0
# 0.50    25.0
# 0.75    54.0
# Name: Runs, dtype: float64

# %%
sns.boxplot(y=df['Runs'])
# Out:
# <Axes: ylabel='Runs'>

# %%
plt.scatter(df['Mins'], df['Runs'])
